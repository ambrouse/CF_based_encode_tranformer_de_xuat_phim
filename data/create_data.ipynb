# %%
import numpy as np
import random
import string
firtf_name_user_ = [
    # Họ 1 chữ
    "Nguyễn", "Trần", "Lê", "Phạm", "Hoàng", "Huỳnh", "Phan", "Vũ", "Võ", "Đặng",
    "Bùi", "Đỗ", "Hồ", "Ngô", "Dương", "Lý", "Tạ", "Tô", "Lâm", "Quách",

    # Họ 2 chữ
    "Lâm Nguyễn", "Trần Anh", "Nguyễn Phúc", "Lê Hoàng", "Đặng Văn", "Phạm Minh",
    "Hồ Thanh", "Vũ Quốc", "Đỗ Hải", "Bùi Gia", "Tô Chấn", "Tạ Bảo", "Ngô Đình",
    "Huỳnh Khắc", "Phan Chí", "Dương Tấn", "Hoàng Nhật", "Võ Đức", "Quách Đạt", "Lý Phong",

    # Họ 3 chữ
    "Nguyễn Lâm Quang", "Trần Đình Phúc", "Phạm Anh Duy", "Đặng Hoàng Nam",
    "Lê Minh Tuấn", "Bùi Văn Tài", "Dương Nhật Khang", "Ngô Quốc Hùng",
    "Võ Đình Long", "Hồ Thanh Phước"
]
last_name_user_ = [
    # Tên 1 chữ
    "An", "Bình", "Cường", "Dũng", "Duy", "Đạt", "Hải", "Hiếu", "Hùng", "Khoa",
    "Khôi", "Lâm", "Long", "Minh", "Nam", "Nhật", "Phong", "Quang", "Sơn", "Tùng",
    "Trang", "Thảo", "Hương", "Lan", "Mai", "My", "Ngọc", "Oanh", "Quyên", "Vy",

    # Tên 2 chữ
    "Anh Duy", "Bảo Khang", "Chí Thành", "Công Danh", "Đình Phúc", "Gia Huy", 
    "Hữu Nghĩa", "Minh Quân", "Nhật Hào", "Quốc Bảo", "Thanh Tùng", "Tuấn Kiệt", 
    "Văn Hậu", "Xuân Phúc", "Yến Nhi", "Thanh Hằng", "Ngọc Trâm", "Bích Thủy", 
    "Thùy Linh", "Ánh Dương"
]
name_movie_list_ = [
    # Phim hành động
    "Kẻ Hủy Diệt", "Rambo: Đổ Máu", "John Wick", "Nhiệm Vụ Bất Khả Thi", "Fast & Furious",
    "Mad Max: Con Đường Cuồng Nộ", "Taken", "Gladiator", "Die Hard", "The Equalizer",
    # Phim khoa học viễn tưởng
    "Ma Trận", "Interstellar", "Inception", "Avatar", "Edge of Tomorrow",
    "The Martian", "Blade Runner 2049", "Dune", "Looper", "Pacific Rim",
    # Phim kinh dị
    "IT", "The Conjuring", "Insidious", "A Quiet Place", "Hereditary",
    "The Exorcist", "Halloween", "The Ring", "Paranormal Activity", "The Nun",
    # Phim hoạt hình
    "Toy Story", "Finding Nemo", "Shrek", "Frozen", "How to Train Your Dragon",
    "The Lion King", "Kung Fu Panda", "Zootopia", "Ratatouille", "Coco",
    # Phim tình cảm
    "The Notebook", "Titanic", "Me Before You", "A Star Is Born", "La La Land",
    "Crazy Rich Asians", "Call Me by Your Name", "The Fault in Our Stars", "Pride & Prejudice", "Love Actually",
    # Phim phiêu lưu
    "Indiana Jones", "The Revenant", "The Hobbit", "Pirates of the Caribbean", "Jumanji",
    "King Kong", "The Jungle Book", "Life of Pi", "The Secret Life of Walter Mitty", "Into the Wild",
    # Phim trinh thám/tội phạm
    "Sherlock Holmes", "Se7en", "Gone Girl", "The Silence of the Lambs", "Zodiac",
    "Prisoners", "The Girl with the Dragon Tattoo", "Knives Out", "Mindhunter", "The Departed",
    # Phim siêu anh hùng
    "The Dark Knight", "Iron Man", "Avengers: Endgame", "Spider-Man: No Way Home", "Doctor Strange",
    "Thor: Ragnarok", "Black Panther", "Man of Steel", "The Batman", "Wonder Woman",
    # Phim chiến tranh
    "Saving Private Ryan", "1917", "Hacksaw Ridge", "Dunkirk", "Platoon",
    "Apocalypse Now", "Fury", "Black Hawk Down", "The Thin Red Line", "Enemy at the Gates",
    # Phim hài
    "Superbad", "The Hangover", "Dumb and Dumber", "Step Brothers", "Anchorman",
    "Deadpool", "We're the Millers", "21 Jump Street", "Zombieland", "Tropic Thunder"
]
movie_scores_ = {
    # Phim hành động
    "Kẻ Hủy Diệt": 8.5, "Rambo: Đổ Máu": 7.8, "John Wick": 8.7, "Nhiệm Vụ Bất Khả Thi": 8.0, "Fast & Furious": 7.5,
    "Mad Max: Con Đường Cuồng Nộ": 8.6, "Taken": 7.9, "Gladiator": 8.8, "Die Hard": 8.2, "The Equalizer": 7.7,
    # Phim khoa học viễn tưởng
    "Ma Trận": 8.7, "Interstellar": 8.6, "Inception": 8.8, "Avatar": 8.0, "Edge of Tomorrow": 7.9,
    "The Martian": 8.0, "Blade Runner 2049": 8.3, "Dune": 8.4, "Looper": 7.4, "Pacific Rim": 7.1,
    # Phim kinh dị
    "IT": 7.3, "The Conjuring": 7.5, "Insidious": 7.0, "A Quiet Place": 7.8, "Hereditary": 7.4,
    "The Exorcist": 8.0, "Halloween": 7.2, "The Ring": 7.1, "Paranormal Activity": 6.3, "The Nun": 5.5,
    # Phim hoạt hình
    "Toy Story": 8.3, "Finding Nemo": 8.1, "Shrek": 8.0, "Frozen": 7.4, "How to Train Your Dragon": 8.1,
    "The Lion King": 8.5, "Kung Fu Panda": 7.8, "Zootopia": 8.0, "Ratatouille": 8.0, "Coco": 8.4,
    # Phim tình cảm
    "The Notebook": 7.9, "Titanic": 8.2, "Me Before You": 7.4, "A Star Is Born": 7.6, "La La Land": 8.0,
    "Crazy Rich Asians": 7.0, "Call Me by Your Name": 8.1, "The Fault in Our Stars": 7.7, "Pride & Prejudice": 8.1, "Love Actually": 7.6,
    # Phim phiêu lưu
    "Indiana Jones": 8.4, "The Revenant": 8.0, "The Hobbit": 7.8, "Pirates of the Caribbean": 8.0, "Jumanji": 7.2,
    "King Kong": 7.5, "The Jungle Book": 7.4, "Life of Pi": 7.9, "The Secret Life of Walter Mitty": 7.3, "Into the Wild": 8.1,
    # Phim trinh thám/tội phạm
    "Sherlock Holmes": 7.6, "Se7en": 8.6, "Gone Girl": 8.1, "The Silence of the Lambs": 8.6, "Zodiac": 7.7,
    "Prisoners": 8.1, "The Girl with the Dragon Tattoo": 7.8, "Knives Out": 7.9, "Mindhunter": 8.0, "The Departed": 8.5,
    # Phim siêu anh hùng
    "The Dark Knight": 9.0, "Iron Man": 8.0, "Avengers: Endgame": 8.4, "Spider-Man: No Way Home": 8.5, "Doctor Strange": 7.8,
    "Thor: Ragnarok": 7.9, "Black Panther": 8.1, "Man of Steel": 7.0, "The Batman": 8.3, "Wonder Woman": 7.4,
    # Phim chiến tranh
    "Saving Private Ryan": 8.6, "1917": 8.3, "Hacksaw Ridge": 8.1, "Dunkirk": 7.9, "Platoon": 8.1,
    "Apocalypse Now": 8.5, "Fury": 7.6, "Black Hawk Down": 7.7, "The Thin Red Line": 7.8, "Enemy at the Gates": 7.5,
    # Phim hài
    "Superbad": 7.6, "The Hangover": 7.7, "Dumb and Dumber": 7.3, "Step Brothers": 6.9, "Anchorman": 7.2,
    "Deadpool": 8.0, "We're the Millers": 7.0, "21 Jump Street": 7.2, "Zombieland": 7.6, "Tropic Thunder": 7.0
}
movie_genres_ = {
"Kẻ Hủy Diệt": ["Hành động", "Khoa học viễn tưởng"], "Rambo: Đổ Máu": ["Hành động", "Chiến tranh"], "John Wick": ["Hành động", "Tội phạm"], "Nhiệm Vụ Bất Khả Thi": ["Hành động", "Phiêu lưu"], "Fast & Furious": ["Hành động", "Tội phạm"], "Mad Max: Con Đường Cuồng Nộ": ["Hành động", "Khoa học viễn tưởng"], "Taken": ["Hành động", "Tội phạm"], "Gladiator": ["Hành động", "Phiêu lưu"], "Die Hard": ["Hành động", "Tội phạm"], "The Equalizer": ["Hành động", "Tội phạm"],
"Ma Trận": ["Khoa học viễn tưởng", "Hành động"], "Interstellar": ["Khoa học viễn tưởng", "Phiêu lưu"], "Inception": ["Khoa học viễn tưởng", "Tội phạm"], "Avatar": ["Khoa học viễn tưởng", "Phiêu lưu"], "Edge of Tomorrow": ["Khoa học viễn tưởng", "Hành động"], "The Martian": ["Khoa học viễn tưởng", "Phiêu lưu"], "Blade Runner 2049": ["Khoa học viễn tưởng", "Tội phạm"], "Dune": ["Khoa học viễn tưởng", "Phiêu lưu"], "Looper": ["Khoa học viễn tưởng", "Tội phạm"], "Pacific Rim": ["Khoa học viễn tưởng", "Hành động"],
"IT": ["Kinh dị"], "The Conjuring": ["Kinh dị"], "Insidious": ["Kinh dị"], "A Quiet Place": ["Kinh dị", "Khoa học viễn tưởng"], "Hereditary": ["Kinh dị"], "The Exorcist": ["Kinh dị"], "Halloween": ["Kinh dị", "Tội phạm"], "The Ring": ["Kinh dị"], "Paranormal Activity": ["Kinh dị"], "The Nun": ["Kinh dị"],
"Toy Story": ["Hoạt hình", "Hài"], "Finding Nemo": ["Hoạt hình", "Phiêu lưu"], "Shrek": ["Hoạt hình", "Hài"], "Frozen": ["Hoạt hình", "Tình cảm"], "How to Train Your Dragon": ["Hoạt hình", "Phiêu lưu"], "The Lion King": ["Hoạt hình", "Phiêu lưu"], "Kung Fu Panda": ["Hoạt hình", "Hành động"], "Zootopia": ["Hoạt hình", "Tội phạm"], "Ratatouille": ["Hoạt hình", "Hài"], "Coco": ["Hoạt hình", "Tình cảm"],
"The Notebook": ["Tình cảm"], "Titanic": ["Tình cảm", "Phiêu lưu"], "Me Before You": ["Tình cảm"], "A Star Is Born": ["Tình cảm", "Nhạc kịch"], "La La Land": ["Tình cảm", "Nhạc kịch"], "Crazy Rich Asians": ["Tình cảm", "Hài"], "Call Me by Your Name": ["Tình cảm"], "The Fault in Our Stars": ["Tình cảm"], "Pride & Prejudice": ["Tình cảm"], "Love Actually": ["Tình cảm", "Hài"],
"Indiana Jones": ["Phiêu lưu", "Hành động"], "The Revenant": ["Phiêu lưu", "Hành động"], "The Hobbit": ["Phiêu lưu", "Khoa học viễn tưởng"], "Pirates of the Caribbean": ["Phiêu lưu", "Hài"], "Jumanji": ["Phiêu lưu", "Hài"], "King Kong": ["Phiêu lưu", "Hành động"], "The Jungle Book": ["Phiêu lưu", "Hoạt hình"], "Life of Pi": ["Phiêu lưu", "Tình cảm"], "The Secret Life of Walter Mitty": ["Phiêu lưu", "Hài"], "Into the Wild": ["Phiêu lưu", "Tình cảm"],
"Sherlock Holmes": ["Tội phạm", "Hành động"], "Se7en": ["Tội phạm", "Kinh dị"], "Gone Girl": ["Tội phạm", "Tình cảm"], "The Silence of the Lambs": ["Tội phạm", "Kinh dị"], "Zodiac": ["Tội phạm", "Trinh thám"], "Prisoners": ["Tội phạm", "Trinh thám"], "The Girl with the Dragon Tattoo": ["Tội phạm", "Trinh thám"], "Knives Out": ["Tội phạm", "Hài"], "Mindhunter": ["Tội phạm", "Trinh thám"], "The Departed": ["Tội phạm", "Hành động"],
"The Dark Knight": ["Siêu anh hùng", "Hành động"], "Iron Man": ["Siêu anh hùng", "Khoa học viễn tưởng"], "Avengers: Endgame": ["Siêu anh hùng", "Khoa học viễn tưởng"], "Spider-Man: No Way Home": ["Siêu anh hùng", "Hành động"], "Doctor Strange": ["Siêu anh hùng", "Khoa học viễn tưởng"], "Thor: Ragnarok": ["Siêu anh hùng", "Hài"], "Black Panther": ["Siêu anh hùng", "Hành động"], "Man of Steel": ["Siêu anh hùng", "Hành động"], "The Batman": ["Siêu anh hùng", "Tội phạm"], "Wonder Woman": ["Siêu anh hùng", "Hành động"],
"Saving Private Ryan": ["Chiến tranh", "Hành động"], "1917": ["Chiến tranh", "Hành động"], "Hacksaw Ridge": ["Chiến tranh", "Tình cảm"], "Dunkirk": ["Chiến tranh", "Hành động"], "Platoon": ["Chiến tranh", "Hành động"], "Apocalypse Now": ["Chiến tranh", "Hành động"], "Fury": ["Chiến tranh", "Hành động"], "Black Hawk Down": ["Chiến tranh", "Hành động"], "The Thin Red Line": ["Chiến tranh", "Tình cảm"], "Enemy at the Gates": ["Chiến tranh", "Tình cảm"],
"Superbad": ["Hài"], "The Hangover": ["Hài"], "Dumb and Dumber": ["Hài"], "Step Brothers": ["Hài"], "Anchorman": ["Hài"], "Deadpool": ["Hài", "Hành động"], "We're the Millers": ["Hài"], "21 Jump Street": ["Hài", "Hành động"], "Zombieland": ["Hài", "Kinh dị"], "Tropic Thunder": ["Hài", "Chiến tranh"]
}
type_movie_list_ = ['Hành động', 'Hài', 'Hoạt hình', 'Khoa học viễn tưởng', 'Kinh dị', 'Nhạc kịch', 'Phiêu lưu', 'Siêu anh hùng', 'Tình cảm', 'Tội phạm', 'Trinh thám', 'Chiến tranh']
coment_movies_list_ = {
    "Kẻ Hủy Diệt": [ "Một bộ phim hành động kinh điển với hình tượng robot sát thủ không thể quên!", "Kẻ Hủy Diệt có cốt truyện viễn tưởng hấp dẫn, cùng với những màn rượt đuổi kịch tính.", "Arnold Schwarzenegger thực sự là linh hồn của bộ phim này!", "Hiệu ứng hình ảnh của phim vẫn rất ấn tượng dù đã ra mắt từ lâu.", "Câu thoại 'I'll be back' đã trở thành huyền thoại trong làng phim hành động." ], "Rambo: Đổ Máu": [ "Hành động mãn nhãn, bạo lực nhưng đầy cảm xúc.", "Rambo luôn là biểu tượng bất diệt của dòng phim hành động!", "Sylvester Stallone thể hiện nhân vật quá xuất sắc, vừa mạnh mẽ vừa bi thương.", "Những cảnh chiến đấu chân thực đến mức nghẹt thở!", "Một bộ phim không chỉ có súng đạn mà còn có chiều sâu về tâm lý nhân vật." ], "John Wick": [ "Phim hành động nhưng có sự tinh tế trong từng pha chiến đấu!", "Nhịp phim nhanh, chiến đấu liên tục nhưng không hề nhàm chán.", "Keanu Reeves là John Wick và John Wick là Keanu Reeves!", "Thế giới sát thủ trong phim quá cuốn hút và có chiều sâu.", "Những cảnh cận chiến trong phim là đỉnh cao của dòng phim hành động." ], "Nhiệm Vụ Bất Khả Thi": [ "Tom Cruise thực sự không biết sợ là gì khi tự mình thực hiện các pha hành động!", "Những pha rượt đuổi, leo trèo và đột nhập luôn căng thẳng đến nghẹt thở.", "Bộ phim có sự kết hợp tuyệt vời giữa hành động, gián điệp và âm mưu chính trị.", "Âm nhạc và các cảnh quay đẹp mắt tạo nên một bộ phim không thể bỏ qua.", "Phần nào của loạt phim cũng đầy bất ngờ và sáng tạo!" ], "Fast & Furious": [ "Xe cộ, tốc độ và những màn đua xe điên rồ – thương hiệu không thể nhầm lẫn!", "Dàn diễn viên cực chất, đặc biệt là Vin Diesel và Paul Walker!", "Cốt truyện ngày càng phi lý nhưng vẫn cực kỳ giải trí!", "Những pha cháy nổ và hành động không tưởng làm nên thương hiệu Fast & Furious.", "Không chỉ là phim đua xe mà còn là câu chuyện về tình anh em!" ], "Mad Max: Con Đường Cuồng Nộ": [ "Một bộ phim hành động hậu tận thế với hình ảnh và âm thanh đỉnh cao!", "Tốc độ, sự điên rồ và những cảnh chiến đấu hoành tráng là điểm nhấn của phim.", "Charlize Theron và Tom Hardy đã tạo nên một cặp đôi biểu tượng!", "Thiết kế xe cộ và thế giới trong phim quá sáng tạo và độc đáo.", "Câu chuyện tuy đơn giản nhưng tạo ra sự hấp dẫn không thể rời mắt!" ], "Taken": [ "Liam Neeson đã biến nhân vật Bryan Mills thành một biểu tượng của dòng phim hành động!", "Câu thoại 'I will find you, and I will kill you' đã trở thành huyền thoại!", "Những pha chiến đấu thực tế và căng thẳng tạo nên một bộ phim cuốn hút.", "Một bộ phim hành động nhưng có cốt truyện đầy cảm xúc về tình cha con.", "Mạch phim nhanh, kịch tính từ đầu đến cuối không hề có giây phút lơi lỏng!" ], "Gladiator": [ "Một bộ phim sử thi xuất sắc với những trận chiến đầy máu lửa!", "Russell Crowe đã mang đến một nhân vật Maximus đầy bi tráng!", "Nhạc phim hoành tráng và đầy cảm xúc, khiến người xem không thể quên!", "Câu thoại 'Are you not entertained?' thực sự đã làm nên dấu ấn của phim!", "Một tác phẩm mang tầm vóc lịch sử, không chỉ là một bộ phim hành động mà còn là một câu chuyện nhân văn!" ], "Die Hard": [ "Bruce Willis đã tạo ra một trong những nhân vật hành động vĩ đại nhất – John McClane!", "Phim hành động nhưng vẫn có sự hài hước rất đặc trưng!", "Những cảnh đối đầu với Hans Gruber cực kỳ kịch tính!", "Một bộ phim Giáng Sinh nhưng đầy súng đạn và cháy nổ!", "Die Hard không chỉ là phim hành động mà còn là một trong những phim kinh điển của Hollywood!" ], "The Equalizer": [ "Denzel Washington mang đến một nhân vật vừa lạnh lùng vừa đầy chiều sâu!", "Những cảnh trả thù trong phim được thực hiện một cách cực kỳ thông minh!", "Một bộ phim hành động nhưng mang phong cách rất khác biệt!", "Từng cảnh chiến đấu trong phim đều có sự tính toán tỉ mỉ!", "Không chỉ là phim hành động, The Equalizer còn có câu chuyện đầy nhân văn!" ],
    "Ma Trận": [ "Một bộ phim khoa học viễn tưởng đột phá với ý tưởng về thực tại ảo đầy ám ảnh!", "Keanu Reeves thực sự đã tạo ra một Neo biểu tượng!", "Những cảnh hành động slow-motion và bullet-time quá kinh điển!", "Cốt truyện sâu sắc, lồng ghép nhiều triết lý về thế giới và con người.", "Dù ra mắt từ lâu nhưng The Matrix vẫn là một chuẩn mực cho dòng phim sci-fi!" ], "Interstellar": [ "Một bộ phim xuất sắc về du hành vũ trụ với những hình ảnh ngoạn mục!", "Nhạc phim của Hans Zimmer quá tuyệt vời, khiến cảm xúc dâng trào!", "Christopher Nolan đã kể một câu chuyện về tình cha con đầy xúc động!", "Các lý thuyết về lỗ đen, thời gian và không gian được truyền tải cực kỳ ấn tượng!", "Mỗi lần xem lại Interstellar là một lần khám phá thêm ý nghĩa mới!" ], "Inception": [ "Một bộ phim khiến người xem phải suy nghĩ về thực tại và giấc mơ!", "Leonardo DiCaprio đã có một vai diễn xuất sắc trong bộ phim đầy phức tạp này!", "Cấu trúc câu chuyện về những tầng giấc mơ được xây dựng cực kỳ tinh vi!", "Kết thúc phim vẫn khiến khán giả tranh cãi về thực hay mơ!", "Nhạc nền của Hans Zimmer khiến từng cảnh quay trở nên cực kỳ mãnh liệt!" ], "Avatar": [ "Một siêu phẩm với hiệu ứng hình ảnh tuyệt vời, tạo ra thế giới Pandora huyền ảo!", "James Cameron đã mang đến một câu chuyện không chỉ đẹp mà còn đầy ý nghĩa!", "Công nghệ CGI của phim thực sự đi trước thời đại!", "Bộ phim m
Một bộ phim truyền cảm hứng với câu chuyện về sự trưởng thành và lòng dũng cảm!", "Nhạc nền trong phim thực sự hoành tráng và đầy cảm xúc!", "Cách mà DreamWorks xây dựng thế giới của những người Viking và rồng rất sáng tạo!" ], "The Lion King": [ "Câu chuyện về Simba là một hành trình trưởng thành đầy cảm xúc và hoành tráng!", "Bản nhạc nền 'Circle of Life' là một trong những ca khúc hoạt hình hay nhất mọi thời đại!", "Bộ phim mang đến nhiều bài học quý giá về cuộc sống và trách nhiệm!", "Hình ảnh thiên nhiên châu Phi trong phim thực sự tuyệt đẹp!", "Mufasa là một trong những nhân vật hoạt hình có ảnh hưởng mạnh mẽ nhất!" ], "Kung Fu Panda": [ "Po là chú gấu trúc đáng yêu nhất với tinh thần chiến đấu không bỏ cuộc!", "Những bài học về kung fu và triết lý trong phim thực sự sâu sắc!", "Shifu và Po có một mối quan hệ thầy trò rất cảm động!", "Những pha hành động trong phim được thiết kế vô cùng đẹp mắt và mãn nhãn!", "Kung Fu Panda là sự kết hợp hoàn hảo giữa hài hước và ý nghĩa!" ], "Zootopia": [ "Một bộ phim hoạt hình với thông điệp sâu sắc về bình đẳng và định kiến xã hội!", "Judy và Nick tạo nên một cặp đôi ăn ý và cực kỳ dễ thương!", "Thành phố động vật Zootopia được thiết kế vô cùng sáng tạo và sống động!", "Bộ phim không chỉ giải trí mà còn có nhiều tầng ý nghĩa rất đáng suy ngẫm!", "Zootopia là một tác phẩm xuất sắc của Disney với nội dung hấp dẫn!" ], "Ratatouille": [ "Remy đã chứng minh rằng ai cũng có thể nấu ăn, ngay cả khi bạn là một chú chuột!", "Cách Pixar thể hiện ẩm thực Pháp trong phim thật sự tinh tế và đẹp mắt!", "Bộ phim truyền cảm hứng cho những ai đam mê ẩm thực và theo đuổi ước mơ!", "Anton Ego có màn thay đổi tâm lý đầy ấn tượng sau khi ăn món Ratatouille!", "Một trong những bộ phim hoạt hình hay nhất về ẩm thực mà tôi từng xem!" ], "Coco": [ "Bộ phim mang đến một câu chuyện xúc động về gia đình và ký ức!", "Hình ảnh thế giới linh hồn trong phim thực sự rực rỡ và đầy sáng tạo!", "Ca khúc 'Remember Me' đã chạm đến trái tim của rất nhiều khán giả!", "Coco là một trong những bộ phim hoạt hình cảm động nhất của Pixar!", "Một tác phẩm xuất sắc với thông điệp ý nghĩa về tình yêu thương gia đình!" ],
    "The Notebook": [ "Câu chuyện tình yêu của Noah và Allie thực sự khiến người ta rơi nước mắt!", "Một bộ phim kinh điển về tình yêu bất diệt và những thử thách của số phận!", "Phân cảnh mưa huyền thoại giữa Noah và Allie là một trong những khoảnh khắc lãng mạn nhất mọi thời đại!", "Ryan Gosling và Rachel McAdams đã mang đến một màn trình diễn quá xuất sắc!", "The Notebook chứng minh rằng tình yêu đích thực có thể vượt qua mọi rào cản!" ], "Titanic": [ "Bộ phim tình cảm kinh điển với câu chuyện đầy bi thương của Jack và Rose!", "Cảnh tàu Titanic chìm vẫn là một trong những khoảnh khắc điện ảnh ấ
Jumanji luôn mang lại sự giải trí tuyệt vời!", "Cảnh vật và các thử thách trong trò chơi thực sự sáng tạo và thú vị!", "Dàn diễn viên xuất sắc đã tạo nên những tình huống cười ra nước mắt!", "Một cuộc phiêu lưu kỳ thú, nơi mọi thứ đều có thể xảy ra!" ], "King Kong": [ "Một bộ phim phiêu lưu huyền thoại về quái vật khổng lồ đầy cảm xúc!", "Cảnh King Kong chiến đấu với khủng long trên đảo Đầu Lâu thực sự mãn nhãn!", "Từ hành động đến cảm xúc, bộ phim đã tạo ra một huyền thoại điện ảnh!", "Mối liên kết giữa King Kong và con người được khai thác rất tốt!", "Một tác phẩm tuyệt vời về thiên nhiên hoang dã và những sinh vật khổng lồ!" ], "The Jungle Book": [ "Một câu chuyện đầy phiêu lưu về tình bạn giữa con người và động vật!", "Kỹ xảo của bộ phim quá ấn tượng, khiến thế giới rừng xanh trở nên sống động!", "Mowgli và những người bạn động vật đã tạo nên một hành trình đáng nhớ!", "Bản nhạc 'The Bare Necessities' vẫn luôn là một giai điệu vui tươi kinh điển!", "Một bộ phim vừa phiêu lưu, vừa ý nghĩa về tình yêu thiên nhiên!" ], "Life of Pi": [ "Một tác phẩm tuyệt đẹp về hành trình sinh tồn giữa đại dương bao la!", "Hình ảnh con hổ Richard Parker cực kỳ chân thực và đầy biểu cảm!", "Life of Pi không chỉ là một cuộc phiêu lưu mà còn là một câu chuyện đầy triết lý!", "Cảnh biển đêm phát sáng là một trong những hình ảnh đẹp nhất trong điện ảnh!", "Bộ phim khiến người xem suy ngẫm về niềm tin và ý nghĩa của cuộc sống!" ], "The Secret Life of Walter Mitty": [ "Một bộ phim đầy cảm hứng về việc thoát khỏi vùng an toàn và dám theo đuổi ước mơ!", "Những cảnh quay tuyệt đẹp từ nhiều quốc gia làm cho bộ phim càng thêm hấp dẫn!", "Walter Mitty từ một người bình thường đã có những chuyến phiêu lưu đáng kinh ngạc!", "Thông điệp về việc sống trọn vẹn từng khoảnh khắc thực sự chạm đến trái tim!", "Một tác phẩm tuyệt vời về tinh thần khám phá và tìm kiếm chính mình!" ], "Into the Wild": [ "Một bộ phim phiêu lưu tuyệt vời với câu chuyện có thật đầy cảm xúc!", "Những cảnh thiên nhiên hùng vĩ khiến người xem như được bước vào cuộc hành trình cùng nhân vật!", "Một tác phẩm đầy ý nghĩa về tự do, cuộc sống và con đường đi tìm bản thân!", "Nhạc phim của Eddie Vedder thực sự tạo nên một bầu không khí hoang dã và sâu lắng!", "Into the Wild khiến người ta suy ngẫm về giá trị của sự tự do và điều gì thực sự quan trọng trong cuộc sống!" ],
    "Sherlock Holmes": [ "Robert Downey Jr. mang đến một phiên bản Sherlock Holmes đầy năng lượng và sắc sảo!", "Những pha suy luận đỉnh cao kết hợp với hành động mãn nhãn khiến bộ phim cực kỳ lôi cuốn!", "Cách xây dựng nhân vật Holmes và Watson quá tuyệt vời, vừa thông minh vừa hài hước!", "Bộ phim mang đến những vụ án hấp dẫn và những màn đấu trí căng thẳng!", "Một s
": [ "Một bộ phim trinh thám hiện đại với phong cách phá án cổ điển cực kỳ thú vị!", "Dàn diễn viên toàn sao cùng kịch bản lắt léo khiến bộ phim vô cùng hấp dẫn!", "Daniel Craig mang đến một thám tử Benoit Blanc đầy thú vị và khác biệt!", "Sự hài hước xen lẫn với những cú twist bất ngờ khiến bộ phim trở nên đặc biệt!", "Knives Out là một luồng gió mới cho thể loại trinh thám Agatha Christie-style!" ], "Mindhunter": [ "Một series trinh thám tâm lý cực kỳ cuốn hút về quá trình nghiên cứu tâm lý tội phạm!", "David Fincher đã tạo nên một bầu không khí cực kỳ căng thẳng mà không cần quá nhiều hành động!", "Các cuộc phỏng vấn với những kẻ sát nhân hàng loạt thực sự rùng mình và chân thực!", "Cách bộ phim khai thác tâm lý tội phạm và sự phát triển của FBI quá hấp dẫn!", "Mindhunter là một trong những series trinh thám hay nhất mà mọi người yêu thích thể loại này nên xem!" ], "The Departed": [ "Một bộ phim tội phạm gay cấn với dàn diễn viên đỉnh cao như Leonardo DiCaprio và Matt Damon!", "Martin Scorsese đã mang đến một tác phẩm trinh thám căng thẳng và đầy kịch tính!", "Những màn đấu trí giữa cảnh sát chìm và tội phạm khiến người xem không thể rời mắt!", "Cái kết bất ngờ và đầy ám ảnh khiến bộ phim trở thành một tượng đài của thể loại này!", "Một trong những bộ phim hay nhất về tội phạm và gián điệp mà bạn không nên bỏ lỡ!" ],
    "The Dark Knight": [ "Heath Ledger đã tạo ra một Joker huyền thoại, không thể thay thế!", "Một bộ phim siêu anh hùng nhưng mang màu sắc tội phạm và tâm lý đầy ám ảnh!", "Christopher Nolan đã nâng tầm thể loại phim siêu anh hùng lên một đẳng cấp khác!", "Cốt truyện kịch tính, nhân vật sâu sắc và những pha hành động nghẹt thở!", "Không chỉ là phim Batman hay nhất mà còn là một trong những phim xuất sắc nhất mọi thời đại!" ], "Iron Man": [ "Robert Downey Jr. chính là Tony Stark bước ra từ truyện tranh!", "Bộ phim đã khởi đầu cho cả vũ trụ điện ảnh Marvel một cách hoàn hảo!", "Sự hài hước, thông minh và những pha hành động mãn nhãn khiến phim cực kỳ cuốn hút!", "Không thể tưởng tượng ai khác ngoài RDJ có thể vào vai Iron Man được!", "Câu chuyện về một thiên tài tự chế tạo bộ giáp để chiến đấu quá hấp dẫn!" ], "Avengers: Endgame": [ "Một cái kết hoàn hảo và đầy cảm xúc cho hơn 10 năm của MCU!", "Trận chiến cuối cùng giữa các siêu anh hùng và Thanos thực sự hoành tráng!", "Cảnh 'Avengers Assemble!' khiến ai cũng phải nổi da gà!", "Tony Stark đã có một lời tạm biệt đầy xúc động và xứng đáng!", "Endgame không chỉ là một bộ phim, mà còn là một sự kiện điện ảnh lịch sử!" ], "Spider-Man: No Way Home": [ "Sự kết hợp của ba thế hệ Spider-Man khiến fan vỡ òa trong cảm xúc!", "Câu chuyện cảm động và trưởng thành hơn bao giờ hết của Peter Parker!", "Những phản diện cũ trở lại nhưng với chiều sâu và câu chuyện mới lạ!", "Một trong những bộ phim Spider-Man hay nhất từng được làm!", "Khi ba Peter cùng chiến đấu, đó là khoảnh khắc không thể nào quên!" ], "Doctor Strange": [ "Hình ảnh và hiệu ứng trong phim thực sự đỉnh cao, như một chuyến du hành vào chiều không gian khác!", "Benedict Cumberbatch đã thể hiện một Doctor Strange thông minh và đầy cá tính!", "Câu chuyện về phép thuật và đa vũ trụ trong MCU bắt đầu từ đây!", "Những màn phép thuật và chiến đấu quá sáng tạo và mãn nhãn!", "Doctor Strange không chỉ mạnh mà còn là nhân vật có chiều sâu tâm lý!" ], "Thor: Ragnarok": [ "Sự hài hước của Taika Waititi đã biến Ragnarok thành một bộ phim đầy vui nhộn!", "Chris Hemsworth cho thấy Thor cũng có thể hài hước và gần gũi hơn!", "Loki và Thor có những khoảnh khắc tình anh em cực kỳ đáng nhớ!", "Hela là một phản diện mạnh mẽ và cực kỳ ấn tượng!", "Một bộ phim giải trí tuyệt vời, không thể rời mắt từ đầu đến cuối!" ], "Black Panther": [ "Wakanda Forever! Một bộ phim siêu anh hùng với văn hóa châu Phi đầy đặc sắc!", "Chadwick Boseman đã mang đến một T’Challa mạnh mẽ và đầy khí chất!", "Killmonger là một trong những phản diện có chiều sâu nhất của MCU!", "Âm nhạc, trang phục và thiết kế trong phim thực sự đỉnh cao!", "Bộ phim không chỉ hay mà còn có ý nghĩa rất lớn về văn hóa và xã hội!" ], "Man of Steel": [ "Một Superman đầy chiều sâu và cảm xúc, khác biệt với những phiên bản trước!", "Henry Cavill hoàn toàn phù hợp với hình tượng Superman mạnh mẽ và uy nghiêm!", "Zack Snyder đã mang đến một bộ phim với hình ảnh và hành động cực kỳ mãn nhãn!", "Nhạc nền của Hans Zimmer đã nâng tầm bộ phim lên một cấp độ khác!", "Cách khai thác nhân vật Clark Kent và hành trình trở thành Superman rất cảm động!" ], "The Batman": [ "Robert Pattinson đã mang đến một Batman trẻ tuổi nhưng đầy u ám và thông minh!", "Bộ phim trinh thám và tội phạm hơn là một phim siêu anh hùng truyền thống!", "The Riddler là một phản diện thông minh và thực sự đáng sợ!", "Bầu không khí Gotham trong phim cực kỳ chân thực và u tối!", "Matt Reeves đã tạo ra một phiên bản Batman rất khác biệt nhưng cực kỳ cuốn hút!" ], "Wonder Woman": [ "Gal Gadot chính là Wonder Woman mà chúng ta luôn mong đợi!", "Bộ phim có những khoảnh khắc chiến đấu cực kỳ hoành tráng và cảm động!", "Cảnh Wonder Woman bước ra từ chiến trường No Man’s Land là một trong những khoảnh khắc tuyệt vời nhất!", "Bộ phim truyền tải thông điệp mạnh mẽ về nữ quyền nhưng không hề gượng ép!", "Một trong những bộ phim siêu anh hùng DC hay nhất, kết hợp hoàn hảo giữa hành động và cảm xúc!" ],
bộ phim siêu anh hùng nhưng phá vỡ mọi quy tắc!", "Những câu thoại hài hước và 'bựa' nhất tôi từng thấy!", "Deadpool không chỉ là siêu anh hùng, mà còn là 'vua hài'!" ], "We're the Millers": [ "Một gia đình giả nhưng đầy những tình huống dở khóc dở cười!", "Jennifer Aniston và Jason Sudeikis có chemistry quá tuyệt!", "Cảnh 'No Ragrets' khiến tôi cười lăn lộn!", "Một bộ phim road trip hài hước nhất mà tôi từng xem!", "Kịch bản sáng tạo, diễn xuất đỉnh, tiếng cười không ngớt!" ], "21 Jump Street": [ "Channing Tatum và Jonah Hill là bộ đôi cảnh sát 'lầy' nhất!", "Một phim hài hành động với những pha gây cười không đỡ nổi!", "Hài hước nhưng vẫn có nhiều cảnh hành động chất lượng!", "Johnny Depp xuất hiện đúng là một cú twist đầy bất ngờ!", "Bộ phim chứng minh rằng quay lại trường trung học không dễ chút nào!" ], "Zombieland": [ "Một bộ phim hài về zombie quá sáng tạo và vui nhộn!", "Quy tắc sống sót của Columbus thực sự hữu ích nếu zombie xuất hiện!", "Woody Harrelson trong vai Tallahassee quá ngầu!", "Bill Murray có một màn cameo huyền thoại!", "Phim zombie nhưng lại đầy tiếng cười, không ai làm được như họ!" ], "Tropic Thunder": [ "Một bộ phim hài châm biếm Hollywood quá xuất sắc!", "Robert Downey Jr. và Tom Cruise có những màn diễn xuất quá đỉnh!", "Những câu thoại trong phim thực sự để đời!", "Sự điên rồ của phim này khiến tôi cười từ đầu đến cuối!", "Một trong những bộ phim hài thông minh và táo bạo nhất!" ]
}
movie_release_years_ = {
    # Phim hành động
    "Kẻ Hủy Diệt": 1984,
    "Rambo: Đổ Máu": 1982,
    "John Wick": 2014,
    "Nhiệm Vụ Bất Khả Thi": 1996,
    "Fast & Furious": 2001,
    "Mad Max: Con Đường Cuồng Nộ": 2015,
    "Taken": 2008,
    "Gladiator": 2000,
    "Die Hard": 1988,
    "The Equalizer": 2014,

    # Phim khoa học viễn tưởng
    "Ma Trận": 1999,
    "Interstellar": 2014,
    "Inception": 2010,
    "Avatar": 2009,
    "Edge of Tomorrow": 2014,
    "The Martian": 2015,
    "Blade Runner 2049": 2017,
    "Dune": 2021,
    "Looper": 2012,
    "Pacific Rim": 2013,

    # Phim kinh dị
    "IT": 2017,
    "The Conjuring": 2013,
    "Insidious": 2010,
    "A Quiet Place": 2018,
    "Hereditary": 2018,
    "The Exorcist": 1973,
    "Halloween": 1978,
    "The Ring": 2002,
    "Paranormal Activity": 2007,
    "The Nun": 2018,

    # Phim hoạt hình
    "Toy Story": 1995,
    "Finding Nemo": 2003,
    "Shrek": 2001,
    "Frozen": 2013,
    "How to Train Your Dragon": 2010,
    "The Lion King": 1994,
    "Kung Fu Panda": 2008,
    "Zootopia": 2016,
    "Ratatouille": 2007,
    "Coco": 2017,

    # Phim tình cảm
    "The Notebook": 2004,
    "Titanic": 1997,
    "Me Before You": 2016,
    "A Star Is Born": 2018,
    "La La Land": 2016,
    "Crazy Rich Asians": 2018,
    "Call Me by Your Name": 2017,
    "The Fault in Our Stars": 2014,
    "Pride & Prejudice": 2005,
    "Love Actually": 2003,

    # Phim phiêu lưu
    "Indiana Jones": 1981,
    "The Revenant": 2015,
    "The Hobbit": 2012,
    "Pirates of the Caribbean": 2003,
    "Jumanji": 1995,
    "King Kong": 2005,
    "The Jungle Book": 2016,
    "Life of Pi": 2012,
    "The Secret Life of Walter Mitty": 2013,
    "Into the Wild": 2007,

    # Phim trinh thám/tội phạm
    "Sherlock Holmes": 2009,
    "Se7en": 1995,
    "Gone Girl": 2014,
    "The Silence of the Lambs": 1991,
    "Zodiac": 2007,
    "Prisoners": 2013,
    "The Girl with the Dragon Tattoo": 2011,
    "Knives Out": 2019,
    "Mindhunter": 2017,  # Đây là series
    "The Departed": 2006,

    # Phim siêu anh hùng
    "The Dark Knight": 2008,
    "Iron Man": 2008,
    "Avengers: Endgame": 2019,
    "Spider-Man: No Way Home": 2021,
    "Doctor Strange": 2016,
    "Thor: Ragnarok": 2017,
    "Black Panther": 2018,
    "Man of Steel": 2013,
    "The Batman": 2022,
    "Wonder Woman": 2017,

    # Phim chiến tranh
    "Saving Private Ryan": 1998,
    "1917": 2019,
    "Hacksaw Ridge": 2016,
    "Dunkirk": 2017,
    "Platoon": 1986,
    "Apocalypse Now": 1979,
    "Fury": 2014,
    "Black Hawk Down": 2001,
    "The Thin Red Line": 1998,
    "Enemy at the Gates": 2001,

    # Phim hài
    "Superbad": 2007,
    "The Hangover": 2009,
    "Dumb and Dumber": 1994,
    "Step Brothers": 2008,
    "Anchorman": 2004,
    "Deadpool": 2016,
    "We're the Millers": 2013,
    "21 Jump Street": 2012,
    "Zombieland": 2009,
    "Tropic Thunder": 2008

}
movie_release_seasons_ = {
    # Phim hành động
    "Kẻ Hủy Diệt": "Hè",  # Tháng 7
    "Rambo: Đổ Máu": "Thu",  # Tháng 10
    "John Wick": "Thu",  # Tháng 10
    "Nhiệm Vụ Bất Khả Thi": "Hè",  # Tháng 5
    "Fast & Furious": "Xuân",  # Tháng 4
    "Mad Max: Con Đường Cuồng Nộ": "Hè",  # Tháng 5
    "Taken": "Đông",  # Tháng 1
    "Gladiator": "Hè",  # Tháng 5
    "Die Hard": "Đông",  # Tháng 7 (Nhưng có chủ đề Giáng Sinh)
    "The Equalizer": "Thu",  # Tháng 9

    # Phim khoa học viễn tưởng
    "Ma Trận": "Xuân",  # Tháng 3
    "Interstellar": "Thu",  # Tháng 11
    "Inception": "Hè",  # Tháng 7
    "Avatar": "Đông",  # Tháng 12
    "Edge of Tomorrow": "Hè",  # Tháng 6
    "The Martian": "Thu",  # Tháng 10
    "Blade Runner 2049": "Thu",  # Tháng 10
    "Dune": "Thu",  # Tháng 10
    "Looper": "Thu",  # Tháng 9
    "Pacific Rim": "Hè",  # Tháng 7

    # Phim kinh dị
    "IT": "Thu",  # Tháng 9
    "The Conjuring": "Hè",  # Tháng 7
    "Insidious": "Xuân",  # Tháng 4
    "A Quiet Place": "Xuân",  # Tháng 4
    "Hereditary": "Hè",  # Tháng 6
    "The Exorcist": "Đông",  # Tháng 12
    "Halloween": "Thu",  # Tháng 10
    "The Ring": "Thu",  # Tháng 10
    "Paranormal Activity": "Thu",  # Tháng 10
    "The Nun": "Thu",  # Tháng 9

    # Phim hoạt hình
    "Toy Story": "Hè",  # Tháng 6
    "Finding Nemo": "Hè",  # Tháng 5
    "Shrek": "Hè",  # Tháng 5
    "Frozen": "Đông",  # Tháng 11
    "How to Train Your Dragon": "Xuân",  # Tháng 3
    "The Lion King": "Hè",  # Tháng 6
    "Kung Fu Panda": "Hè",  # Tháng 6
    "Zootopia": "Xuân",  # Tháng 3
    "Ratatouille": "Hè",  # Tháng 6
    "Coco": "Thu",  # Tháng 11

    # Phim tình cảm
    "The Notebook": "Hè",  # Tháng 6
    "Titanic": "Đông",  # Tháng 12
    "Me Before You": "Hè",  # Tháng 6
    "A Star Is Born": "Thu",  # Tháng 10
    "La La Land": "Đông",  # Tháng 12
    "Crazy Rich Asians": "Hè",  # Tháng 8
    "Call Me by Your Name": "Thu",  # Tháng 11
    "The Fault in Our Stars": "Hè",  # Tháng 6
    "Pride & Prejudice": "Thu",  # Tháng 9
    "Love Actually": "Đông",  # Tháng 11

    # Phim phiêu lưu
    "Indiana Jones": "Hè",  # Tháng 6
    "The Revenant": "Đông",  # Tháng 12
    "The Hobbit": "Đông",  # Tháng 12
    "Pirates of the Caribbean": "Hè",  # Tháng 7
    "Jumanji": "Đông",  # Tháng 12
    "King Kong": "Đông",  # Tháng 12
    "The Jungle Book": "Xuân",  # Tháng 4
    "Life of Pi": "Thu",  # Tháng 11
    "The Secret Life of Walter Mitty": "Đông",  # Tháng 12
    "Into the Wild": "Thu",  # Tháng 9

    # Phim trinh thám/tội phạm
    "Sherlock Holmes": "Đông",  # Tháng 12
    "Se7en": "Thu",  # Tháng 9
    "Gone Girl": "Thu",  # Tháng 10
    "The Silence of the Lambs": "Xuân",  # Tháng 2
    "Zodiac": "Xuân",  # Tháng 3
    "Prisoners": "Thu",  # Tháng 9
    "The Girl with the Dragon Tattoo": "Đông",  # Tháng 12
    "Knives Out": "Thu",  # Tháng 11
    "Mindhunter": "Thu",  # Tháng 10 (Series Netflix)
    "The Departed": "Thu",  # Tháng 10

    # Phim siêu anh hùng
    "The Dark Knight": "Hè",  # Tháng 7
    "Iron Man": "Hè",  # Tháng 5
    "Avengers: Endgame": "Xuân",  # Tháng 4
    "Spider-Man: No Way Home": "Đông",  # Tháng 12
    "Doctor Strange": "Thu",  # Tháng 11
    "Thor: Ragnarok": "Thu",  # Tháng 11
    "Black Panther": "Xuân",  # Tháng 2
    "Man of Steel": "Hè",  # Tháng 6
    "The Batman": "Xuân",  # Tháng 3
    "Wonder Woman": "Hè",  # Tháng 6

    # Phim chiến tranh
    "Saving Private Ryan": "Hè",  # Tháng 7
    "1917": "Đông",  # Tháng 12
    "Hacksaw Ridge": "Thu",  # Tháng 11
    "Dunkirk": "Hè",  # Tháng 7
    "Platoon": "Đông",  # Tháng 12
    "Apocalypse Now": "Hè",  # Tháng 8
    "Fury": "Thu",  # Tháng 10
    "Black Hawk Down": "Đông",  # Tháng 12
    "The Thin Red Line": "Đông",  # Tháng 12
    "Enemy at the Gates": "Xuân",  # Tháng 3

    # Phim hài
    "Superbad": "Hè",  # Tháng 8
    "The Hangover": "Hè",  # Tháng 6
    "Dumb and Dumber": "Đông",  # Tháng 12
    "Step Brothers": "Hè",  # Tháng 7
    "Anchorman": "Hè",  # Tháng 7
    "Deadpool": "Xuân",  # Tháng 2
    "We're the Millers": "Hè",  # Tháng 8
    "21 Jump Street": "Xuân",  # Tháng 3
    "Zombieland": "Thu",  # Tháng 10
    "Tropic Thunder": "Hè"  # Tháng 8
}
movie_probabilities_list_ = {
    # Phim hành động
    "Kẻ Hủy Diệt": 0.85, "Rambo: Đổ Máu": 0.78, "John Wick": 0.92, "Nhiệm Vụ Bất Khả Thi": 0.88, "Fast & Furious": 0.90,
    "Mad Max: Con Đường Cuồng Nộ": 0.80, "Taken": 0.75, "Gladiator": 0.82, "Die Hard": 0.84, "The Equalizer": 0.76,
    # Phim khoa học viễn tưởng
    "Ma Trận": 0.95, "Interstellar": 0.93, "Inception": 0.94, "Avatar": 0.97, "Edge of Tomorrow": 0.89,
    "The Martian": 0.91, "Blade Runner 2049": 0.87, "Dune": 0.90, "Looper": 0.86, "Pacific Rim": 0.88,
    # Phim kinh dị
    "IT": 0.74, "The Conjuring": 0.77, "Insidious": 0.73, "A Quiet Place": 0.79, "Hereditary": 0.72,
    "The Exorcist": 0.70, "Halloween": 0.71, "The Ring": 0.69, "Paranormal Activity": 0.68, "The Nun": 0.66,
    # Phim hoạt hình
    "Toy Story": 0.96, "Finding Nemo": 0.95, "Shrek": 0.94, "Frozen": 0.97, "How to Train Your Dragon": 0.93,
    "The Lion King": 0.98, "Kung Fu Panda": 0.92, "Zootopia": 0.95, "Ratatouille": 0.91, "Coco": 0.96,
    # Phim tình cảm
    "The Notebook": 0.89, "Titanic": 0.99, "Me Before You": 0.88, "A Star Is Born": 0.90, "La La Land": 0.87,
    "Crazy Rich Asians": 0.85, "Call Me by Your Name": 0.83, "The Fault in Our Stars": 0.82, "Pride & Prejudice": 0.80, "Love Actually": 0.81,
    # Phim phiêu lưu
    "Indiana Jones": 0.94, "The Revenant": 0.90, "The Hobbit": 0.91, "Pirates of the Caribbean": 0.95, "Jumanji": 0.89,
    "King Kong": 0.87, "The Jungle Book": 0.86, "Life of Pi": 0.85, "The Secret Life of Walter Mitty": 0.84, "Into the Wild": 0.82,
    # Phim trinh thám/tội phạm
    "Sherlock Holmes": 0.93, "Se7en": 0.92, "Gone Girl": 0.91, "The Silence of the Lambs": 0.95, "Zodiac": 0.88,
    "Prisoners": 0.89, "The Girl with the Dragon Tattoo": 0.87, "Knives Out": 0.90, "Mindhunter": 0.85, "The Departed": 0.94,
    # Phim siêu anh hùng
    "The Dark Knight": 0.98, "Iron Man": 0.97, "Avengers: Endgame": 0.99, "Spider-Man: No Way Home": 0.96, "Doctor Strange": 0.94,
    "Thor: Ragnarok": 0.93, "Black Panther": 0.95, "Man of Steel": 0.89, "The Batman": 0.92, "Wonder Woman": 0.90,
    # Phim chiến tranh
    "Saving Private Ryan": 0.96, "1917": 0.94, "Hacksaw Ridge": 0.93, "Dunkirk": 0.95, "Platoon": 0.89,
    "Apocalypse Now": 0.88, "Fury": 0.90, "Black Hawk Down": 0.87, "The Thin Red Line": 0.85, "Enemy at the Gates": 0.83,
    # Phim hài
    "Superbad": 0.84, "The Hangover": 0.86, "Dumb and Dumber": 0.82, "Step Brothers": 0.80, "Anchorman": 0.78,
    "Deadpool": 0.92, "We're the Millers": 0.81, "21 Jump Street": 0.83, "Zombieland": 0.87, "Tropic Thunder": 0.85
}
phim_nam_ = [
    # Phim hành động
    "Kẻ Hủy Diệt", "Rambo: Đổ Máu", "John Wick", "Nhiệm Vụ Bất Khả Thi", "Fast & Furious",
    "Mad Max: Con Đường Cuồng Nộ", "Taken", "Gladiator", "Die Hard", "The Equalizer",
    # Phim khoa học viễn tưởng
    "Ma Trận", "Interstellar", "Inception", "Avatar", "Edge of Tomorrow",
    "The Martian", "Blade Runner 2049", "Dune", "Looper", "Pacific Rim",
    # Phim phiêu lưu
    "Indiana Jones", "The Revenant", "The Hobbit", "Pirates of the Caribbean", "Jumanji",
    "King Kong", "The Jungle Book", "Life of Pi",
    # Phim trinh thám/tội phạm
    "Sherlock Holmes", "Se7en", "The Silence of the Lambs", "Zodiac", "Prisoners", 
    "Knives Out", "The Departed",
    # Phim siêu anh hùng
    "The Dark Knight", "Iron Man", "Avengers: Endgame", "Spider-Man: No Way Home", "Doctor Strange",
    "Thor: Ragnarok", "Black Panther", "Man of Steel", "The Batman", "Wonder Woman",
    # Phim chiến tranh
    "Saving Private Ryan", "1917", "Hacksaw Ridge", "Dunkirk", "Platoon",
    "Apocalypse Now", "Fury", "Black Hawk Down", "The Thin Red Line", "Enemy at the Gates",
    # Phim hài
    "Superbad", "The Hangover", "Dumb and Dumber", "Step Brothers", "Anchorman",
    "Deadpool", "We're the Millers", "21 Jump Street", "Zombieland", "Tropic Thunder"
]
movie_age_mapping_ = {
    # Phim hành động
    "Kẻ Hủy Diệt": 35, "Rambo: Đổ Máu": 40, "John Wick": 28, "Nhiệm Vụ Bất Khả Thi": 30, "Fast & Furious": 25,
    "Mad Max: Con Đường Cuồng Nộ": 27, "Taken": 33, "Gladiator": 38, "Die Hard": 36, "The Equalizer": 34,

    # Phim khoa học viễn tưởng
    "Ma Trận": 32, "Interstellar": 29, "Inception": 28, "Avatar": 26, "Edge of Tomorrow": 27,
    "The Martian": 31, "Blade Runner 2049": 30, "Dune": 26, "Looper": 28, "Pacific Rim": 24,

    # Phim kinh dị
    "IT": 22, "The Conjuring": 23, "Insidious": 21, "A Quiet Place": 24, "Hereditary": 25,
    "The Exorcist": 45, "Halloween": 43, "The Ring": 35, "Paranormal Activity": 20, "The Nun": 22,

    # Phim hoạt hình
    "Toy Story": 8, "Finding Nemo": 7, "Shrek": 10, "Frozen": 9, "How to Train Your Dragon": 11,
    "The Lion King": 12, "Kung Fu Panda": 13, "Zootopia": 14, "Ratatouille": 13, "Coco": 15,

    # Phim tình cảm
    "The Notebook": 30, "Titanic": 35, "Me Before You": 26, "A Star Is Born": 32, "La La Land": 29,
    "Crazy Rich Asians": 27, "Call Me by Your Name": 24, "The Fault in Our Stars": 23, "Pride & Prejudice": 34, "Love Actually": 36,

    # Phim phiêu lưu
    "Indiana Jones": 40, "The Revenant": 38, "The Hobbit": 30, "Pirates of the Caribbean": 28, "Jumanji": 20,
    "King Kong": 35, "The Jungle Book": 16, "Life of Pi": 25, "The Secret Life of Walter Mitty": 31, "Into the Wild": 27,

    # Phim trinh thám/tội phạm
    "Sherlock Holmes": 34, "Se7en": 37, "Gone Girl": 36, "The Silence of the Lambs": 38, "Zodiac": 39,
    "Prisoners": 40, "The Girl with the Dragon Tattoo": 35, "Knives Out": 28, "Mindhunter": 33, "The Departed": 38,

    # Phim siêu anh hùng
    "The Dark Knight": 30, "Iron Man": 25, "Avengers: Endgame": 24, "Spider-Man: No Way Home": 20, "Doctor Strange": 26,
    "Thor: Ragnarok": 24, "Black Panther": 23, "Man of Steel": 27, "The Batman": 29, "Wonder Woman": 25,

    # Phim chiến tranh
    "Saving Private Ryan": 45, "1917": 40, "Hacksaw Ridge": 38, "Dunkirk": 37, "Platoon": 50,
    "Apocalypse Now": 55, "Fury": 42, "Black Hawk Down": 39, "The Thin Red Line": 47, "Enemy at the Gates": 44,

    # Phim hài
    "Superbad": 18, "The Hangover": 22, "Dumb and Dumber": 25, "Step Brothers": 26, "Anchorman": 27,
    "Deadpool": 24, "We're the Millers": 23, "21 Jump Street": 20, "Zombieland": 22, "Tropic Thunder": 28
}
the_loai_pho_bien_ = [
    "Hành động", "Khoa học viễn tưởng", "Tội phạm", "Phiêu lưu", 
    "Siêu anh hùng", "Tình cảm", "Hoạt hình"
]
movie_descriptions_list_ = {
# Phim hành động
    "Kẻ Hủy Diệt": "Phim hành động khoa học viễn tưởng về người máy sát thủ từ tương lai.",
    "Rambo: Đổ Máu": "Phim hành động chiến tranh xoay quanh cựu binh Rambo và những trận chiến khốc liệt.",
    "John Wick": "Phim hành động về sát thủ huyền thoại với những màn chiến đấu mãn nhãn.",
    "Nhiệm Vụ Bất Khả Thi": "Phim hành động gián điệp với những nhiệm vụ bất khả thi đầy kịch tính.",
    "Fast & Furious": "Phim hành động tốc độ với những màn đua xe và cháy nổ hoành tráng.",
    "Mad Max: Con Đường Cuồng Nộ": "Phim hành động hậu tận thế với những cuộc rượt đuổi điên cuồng.",
    "Taken": "Phim hành động tội phạm về một cựu đặc vụ truy tìm con gái bị bắt cóc.",
    "Gladiator": "Phim hành động sử thi về đấu sĩ La Mã và cuộc chiến giành danh dự.",
    "Die Hard": "Phim hành động kinh điển về một cảnh sát đối đầu khủng bố trong tòa nhà cao tầng.",
    "The Equalizer": "Phim hành động về một cựu đặc vụ ra tay trừng trị kẻ xấu để bảo vệ người vô tội.",
    
    # Phim khoa học viễn tưởng
    "Ma Trận": "Phim khoa học viễn tưởng về thế giới ảo và cuộc chiến giữa con người và máy móc.",
    "Interstellar": "Phim khoa học viễn tưởng về du hành vũ trụ và tình yêu vượt không gian, thời gian.",
    "Inception": "Phim khoa học viễn tưởng về giấc mơ trong giấc mơ và hành trình thao túng tiềm thức.",
    "Avatar": "Phim khoa học viễn tưởng về hành tinh Pandora và cuộc chiến giành tự do.",
    "Edge of Tomorrow": "Phim khoa học viễn tưởng về vòng lặp thời gian và cuộc chiến chống quái vật ngoài hành tinh.",
    "The Martian": "Phim khoa học viễn tưởng về một phi hành gia tìm cách sống sót trên sao Hỏa.",
    "Blade Runner 2049": "Phim khoa học viễn tưởng về tương lai, con người nhân bản và trí tuệ nhân tạo.",
    "Dune": "Phim khoa học viễn tưởng sử thi về cuộc chiến tranh giành quyền lực trên hành tinh Arrakis.",
    "Looper": "Phim khoa học viễn tưởng về sát thủ du hành thời gian và những nghịch lý thời gian.",
    "Pacific Rim": "Phim khoa học viễn tưởng về cuộc chiến giữa con người và quái vật khổng lồ Kaiju.",

    # Phim kinh dị
    "IT": "Phim kinh dị về một con quái vật hề chuyên săn lùng trẻ em.",
    "The Conjuring": "Phim kinh dị về các vụ điều tra hiện tượng siêu nhiên rùng rợn.",
    "Insidious": "Phim kinh dị về một gia đình bị quỷ ám và những hiện tượng đáng sợ.",
    "A Quiet Place": "Phim kinh dị sinh tồn về một thế giới không được phát ra âm thanh nếu không sẽ bị săn lùng.",
    "Hereditary": "Phim kinh dị tâm lý về những bí ẩn gia tộc và nỗi ám ảnh kinh hoàng.",
    "The Exorcist": "Phim kinh dị kinh điển về trừ tà và cuộc chiến chống quỷ dữ.",
    "Halloween": "Phim kinh dị sát nhân về kẻ giết người hàng loạt mang mặt nạ bí ẩn.",
    "The Ring": "Phim kinh dị về một cuốn băng ma ám gây ra cái chết khủng khiếp.",
    "Paranormal Activity": "Phim kinh dị giả tài liệu về những hiện tượng siêu nhiên đáng sợ.",
    "The Nun": "Phim kinh dị về một nữ tu quỷ ám gieo rắc nỗi kinh hoàng.",

    # Phim hoạt hình
    "Toy Story": "Phim hoạt hình về thế giới đồ chơi sống động và tình bạn đầy cảm xúc.",
    "Finding Nemo": "Phim hoạt hình về hành trình tìm con đầy phiêu lưu dưới đáy đại dương.",
    "Shrek": "Phim hoạt hình hài hước về một gã chằn tinh và cuộc phiêu lưu kỳ lạ.",
    "Frozen": "Phim hoạt hình âm nhạc về tình chị em và phép thuật băng giá.",
    "How to Train Your Dragon": "Phim hoạt hình về tình bạn giữa cậu bé Viking và rồng.",
    "The Lion King": "Phim hoạt hình sử thi về hành trình trưởng thành của một chú sư tử trẻ.",
    "Kung Fu Panda": "Phim hoạt hình hài hước về một chú gấu trúc võ thuật.",
    "Zootopia": "Phim hoạt hình về một thành phố động vật và một cuộc điều tra bí ẩn.",
    "Ratatouille": "Phim hoạt hình về một chú chuột yêu nấu ăn và ước mơ làm đầu bếp.",
    "Coco": "Phim hoạt hình về âm nhạc, gia đình và chuyến phiêu lưu vào thế giới người chết.",

    # Phim tình cảm
    "The Notebook": "Phim tình cảm lãng mạn về tình yêu vĩnh cửu và những hồi ức.",
    "Titanic": "Phim tình cảm kinh điển về chuyện tình bi thương trên con tàu huyền thoại.",
    "Me Before You": "Phim tình cảm đầy cảm động về cô gái vui vẻ và chàng trai tàn tật.",
    "A Star Is Born": "Phim tình cảm âm nhạc về tình yêu và sự nổi tiếng.",
    "La La Land": "Phim tình cảm âm nhạc về đam mê, ước mơ và tình yêu.",
    "Crazy Rich Asians": "Phim tình cảm hài về tình yêu giữa hai con người từ hai thế giới khác nhau.",
    "Call Me by Your Name": "Phim tình cảm đồng tính về mối tình mùa hè đầu đời.",
    "The Fault in Our Stars": "Phim tình cảm cảm động về tình yêu giữa hai bệnh nhân ung thư.",
    "Pride & Prejudice": "Phim tình cảm cổ điển dựa trên tiểu thuyết nổi tiếng của Jane Austen.",
    "Love Actually": "Phim tình cảm lãng mạn về nhiều câu chuyện tình yêu đan xen.",

    # Phim phiêu lưu
    "Indiana Jones": "Phim phiêu lưu kinh điển về nhà khảo cổ học gan dạ và những cuộc truy tìm báu vật.",
    "The Revenant": "Phim phiêu lưu sinh tồn về một người đàn ông sống sót giữa thiên nhiên hoang dã.",
    "The Hobbit": "Phim phiêu lưu giả tưởng về hành trình của một người Hobbit đi tìm kho báu rồng.",
    "Pirates of the Caribbean": "Phim phiêu lưu về những tên cướp biển và cuộc chiến trên đại dương.",
    "Jumanji": "Phim phiêu lưu kỳ ảo về một trò chơi board game có thể thay đổi thực tại.",
    "King Kong": "Phim phiêu lưu hành động về cuộc đối đầu với quái vật khổng lồ trên đảo hoang.",
    "The Jungle Book": "Phim phiêu lưu hoạt hình về cậu bé rừng xanh sống cùng thú hoang.",
    "Life of Pi": "Phim phiêu lưu kỳ ảo về một cậu bé bị lạc giữa đại dương cùng một con hổ.",
    "The Secret Life of Walter Mitty": "Phim phiêu lưu truyền cảm hứng về hành trình khám phá thế giới thực.",
    "Into the Wild": "Phim phiêu lưu về cuộc sống tự do trong thiên nhiên hoang dã.",

    # Phim trinh thám/tội phạm
    "Sherlock Holmes": "Phim trinh thám về thám tử lừng danh và những vụ án phức tạp.",
    "Se7en": "Phim trinh thám tâm lý về cuộc điều tra kẻ sát nhân hàng loạt với bảy tội lỗi chết người.",
    "Gone Girl": "Phim trinh thám tâm lý về sự mất tích bí ẩn của một người vợ.",
    "The Silence of the Lambs": "Phim trinh thám kinh dị về bác sĩ tâm thần ăn thịt người Hannibal Lecter.",
    "Zodiac": "Phim trinh thám dựa trên câu chuyện có thật về kẻ sát nhân Zodiac bí ẩn.",
    "Prisoners": "Phim trinh thám tội phạm về cuộc tìm kiếm đứa trẻ mất tích.",
    "The Girl with the Dragon Tattoo": "Phim trinh thám về hacker thiên tài và vụ án giết người bí ẩn.",
    "Knives Out": "Phim trinh thám hài hước về vụ án giết người với nhiều nghi phạm.",
    "Mindhunter": "Phim trinh thám tâm lý về những cuộc điều tra kẻ sát nhân hàng loạt.",
    "The Departed": "Phim tội phạm về cuộc đối đầu giữa cảnh sát chìm và tội phạm ẩn mình.",

    # Phim siêu anh hùng
    "The Dark Knight": "Phim siêu anh hùng về Batman đối đầu với Joker trong một cuộc chiến tâm lý căng thẳng.",
    "Iron Man": "Phim siêu anh hùng về Tony Stark và bộ giáp công nghệ tiên tiến của anh.",
    "Avengers: Endgame": "Phim siêu anh hùng hoành tráng về cuộc chiến cuối cùng chống lại Thanos.",
    "Spider-Man: No Way Home": "Phim siêu anh hùng về Spider-Man và cuộc đối đầu với các phản diện từ đa vũ trụ.",
    "Doctor Strange": "Phim siêu anh hùng về pháp sư tối thượng với những phép thuật huyền bí.",
    "Thor: Ragnarok": "Phim siêu anh hùng về Thor và trận chiến để cứu lấy Asgard.",
    "Black Panther": "Phim siêu anh hùng về vị vua Wakanda và cuộc chiến bảo vệ quê hương.",
    "Man of Steel": "Phim siêu anh hùng kể về hành trình trở thành Superman của Clark Kent.",
    "The Batman": "Phim siêu anh hùng về Batman trong cuộc điều tra tội ác tại Gotham.",
    "Wonder Woman": "Phim siêu anh hùng về nữ chiến binh Amazon chiến đấu bảo vệ thế giới.",

    # Phim chiến tranh
    "Saving Private Ryan": "Phim chiến tranh sử thi về cuộc giải cứu một binh sĩ trong Thế chiến II.",
    "1917": "Phim chiến tranh về hành trình của hai lính Anh mang thông điệp quan trọng.",
    "Hacksaw Ridge": "Phim chiến tranh dựa trên câu chuyện có thật về người lính không cầm súng.",
    "Dunkirk": "Phim chiến tranh về cuộc di tản thần kỳ của quân Đồng Minh khỏi Dunkirk.",
    "Platoon": "Phim chiến tranh chân thực về sự tàn khốc của cuộc chiến tại Việt Nam.",
    "Apocalypse Now": "Phim chiến tranh tâm lý về một nhiệm vụ bí mật trong rừng rậm Việt Nam.",
    "Fury": "Phim chiến tranh về đội xe tăng Mỹ đối đầu quân Đức Quốc xã.",
    "Black Hawk Down": "Phim chiến tranh hiện đại về cuộc chiến sinh tồn tại Somalia.",
    "The Thin Red Line": "Phim chiến tranh triết lý về cuộc chiến Thái Bình Dương.",
    "Enemy at the Gates": "Phim chiến tranh về cuộc đối đầu của hai tay súng bắn tỉa tại Stalingrad.",

    # Phim hài
    "Superbad": "Phim hài về tuổi trẻ nổi loạn và những tình huống dở khóc dở cười.",
    "The Hangover": "Phim hài về một nhóm bạn thân tỉnh dậy sau một đêm quậy phá và không nhớ gì.",
    "Dumb and Dumber": "Phim hài siêu ngốc về hai chàng trai ngớ ngẩn với những pha hành động cười ra nước mắt.",
    "Step Brothers": "Phim hài về hai gã đàn ông trưởng thành phải sống chung như anh em.",
    "Anchorman": "Phim hài về thế giới truyền hình với những màn đối đầu hài hước.",
    "Deadpool": "Phim hài siêu anh hùng với phong cách châm biếm và những pha hành động bá đạo.",
    "We're the Millers": "Phim hài về một nhóm người giả làm gia đình để buôn lậu ma túy.",
    "21 Jump Street": "Phim hài hành động về hai cảnh sát chìm giả dạng học sinh trung học.",
    "Zombieland": "Phim hài kinh dị về nhóm người sống sót trong đại dịch zombie.",
    "Tropic Thunder": "Phim hài châm biếm về một nhóm diễn viên lạc trong khu rừng chiến tranh thật.",

}

# %%
num_samples = 500_000
for i in range(1):
    with open(f"synthetic_data_0.txt", "w", encoding="utf-8") as f:
        for _ in range(num_samples):
            name_ = random.choice(firtf_name_user_)+" "+random.choice(last_name_user_)
            name_movie_ = random.choice(name_movie_list_)
            age_ = random.randint(18, 70)
            user_month_ = random.randint(1, 13)
            user_day_ = random.randint(1, 28)
            name_movie_10_ = [random.choice(name_movie_list_) for i in range(10)]
            type_movie_ = movie_genres_[name_movie_]
            type_movie_10_ = list(set([", ".join(movie_genres_[i]) for i in name_movie_10_]))
            best_type_ = random.choice(type_movie_list_)
            scores_movie_10_ = [movie_scores_[i] for i in name_movie_10_]
            scores_movie_ = movie_scores_[name_movie_]
            coment_movies_ = coment_movies_list_[name_movie_]
            year_movies_ = movie_release_years_[name_movie_]
            count_watched_movies_ = random.randint(0,1000)
            seasion_ = movie_release_seasons_[name_movie_] 
            sex_ = random.randint(0, 1)
            movie_descriptions_ = movie_descriptions_list_[name_movie_]
            
            
            
            # Quy luật ẩn: Người mua có click cao, rating cao, giảm giá, khoảng cách mua gần
            buy_prob = (
                (1 if age_ == movie_age_mapping_[name_movie_] else -1) * 0.0588 + 
                (1 if scores_movie_ > 6 else -1) * 0.0588 + 
                (1 if age_ < 40 else -1) * 0.0588 + 
                (1 if user_month_ < 6 else -1) * 0.0588 + 
                (1 if user_day_ < 15 else -1) * 0.0588 + 
                (1 if type_movie_ in the_loai_pho_bien_ else -1) * 0.0588 + 
                (1 if best_type_ in type_movie_  else -1) * 0.0588 + 
                (1 if best_type_ in type_movie_10_  else -1) * 0.0588 + 
                (1 if set(type_movie_) & set(type_movie_10_) != set() else -1) * 0.0588 + 
                (1 if set(type_movie_) & set(the_loai_pho_bien_) != set() else -1) * 0.0588 + 
                (1 if seasion_ == "Mùa Xuân" and name_movie_ in ["La La Land", "The Secret Life of Walter Mitty", "Toy Story", "Finding Nemo","Zootopia", 
                                                                "Kung Fu Panda", "The Lion King", "Crazy Rich Asians","Love Actually", "Call Me by Your Name", 
                                                                "The Fault in Our Stars", "Me Before You"] else -1) * 0.0588 +
                (1 if seasion_ == "Mùa Hè" and name_movie_ in [ "Fast & Furious", "John Wick", "Nhiệm Vụ Bất Khả Thi", "Mad Max: Con Đường Cuồng Nộ", "Indiana Jones",
                                                                "Pirates of the Caribbean", "Jumanji", "Pacific Rim", "Spider-Man: No Way Home", "Avengers: Endgame", 
                                                                "Thor: Ragnarok", "Iron Man", "The Martian", "Edge of Tomorrow", "Dune", "Avatar" ] else -1) * 0.0588 +
                (1 if seasion_ == "Mùa Thu" and name_movie_ in [ "Se7en", "Gone Girl", "Zodiac", "The Silence of the Lambs", "Knives Out", "Mindhunter", "The Departed",
                                                                 "Prisoners", "The Girl with the Dragon Tattoo", "IT", "The Conjuring", "A Quiet Place", "Hereditary",
                                                                   "Halloween", "Sherlock Holmes", "Inception", "Blade Runner 2049" ] else -1) * 0.0588 +
                (1 if seasion_ == "Mùa Đông" and name_movie_ in [ "Titanic", "The Notebook", "Pride & Prejudice", "A Star Is Born", "Frozen", "Coco", "How to Train Your Dragon",
                                                                  "Ratatouille", "The Revenant", "The Hobbit", "King Kong", "The Jungle Book", "Saving Private Ryan", "1917", "Hacksaw Ridge", "Dunkirk" ] else -1) * 0.0588 +
                (1 if int(sex_) == 0 and name_movie_ in phim_nam_ else -1) * 0.0588 +
                movie_probabilities_list_[name_movie_] +
                count_watched_movies_ * 0.0001
                
            )
            buy_prob = min(max(buy_prob, 0), 1)

            if(_ < num_samples*0.9):
                label = 1 if buy_prob > 0.5 else 0
            else:
                label = 1 if buy_prob > random.random() else 0
            data = [
                name_,
                name_movie_,
                str(age_),
                str(user_month_),
                str(user_day_),
                ", ".join(name_movie_10_),
                ", ".join(type_movie_),
                ", ".join(type_movie_10_),
                best_type_,
                ", ".join([str(i) for i in scores_movie_10_]),
                str(scores_movie_),
                movie_descriptions_,
                ", ".join(coment_movies_),
                str(year_movies_),
                str(count_watched_movies_),
                seasion_,
                str(sex_),
                str(label)
            ]
            f.write("_".join(data) + "\n")
    
    print("Synthetic dataset with hidden rules generated successfully!")
# Out:
# Synthetic dataset with hidden rules generated successfully!

# %%
import pandas as pd 
# load data
"""
    Đọc file txt 
"""
data_collum_ = np.loadtxt("collum.txt", dtype=str, delimiter=",", encoding="utf-8")
print("Name collum")
for i in range(len(data_collum_)):
    print(f"-{i}, {data_collum_[i]}")
    
df = pd.read_csv("synthetic_data_4.txt", delimiter="_", header=None)
print(df.head(1))
print(df.shape)
# Out:
# Name collum
# -0, tên người dùng
# -1,  tên phim
# -2,  tuổi
# -3,  ngày sinh
# -4,  tháng sinh
# -5,  tên 10 phim đã xem gần nhất
# -6,  thể loại phim
# -7,  thể loại 10 phim gần nhất đã xem
# -8,  thể loại xem nhiều nhất
# -9,  số điểm của 10 phim đã xem
# -10,  điểm của phim
# -11,  mô tả phim
# -12,  5 bình luận của phim
# -13,  năm ra mắt phim
# -14,  số lượng phim đã xem
# -15,  mùa ra mắt
# -16,  gioi tinh
# -17,  nhãn
#                  0     1   2   3   4   \
# 0  Nguyễn Minh Quân  Fury  18   6  19
#
#                                                   5                       6   \
# 0  Man of Steel, Ma Trận, Paranormal Activity, Lo...  Chiến tranh, Hành động
#
#                                                   7        8   \
# 0  Khoa học viễn tưởng, Hành động, Chiến tranh, H...  Kinh dị
#
#                                                  9    10  \
# 0  7.0, 8.7, 6.3, 7.4, 8.0, 7.1, 7.7, 7.2, 7.0, 7.9  7.6
#
#                                                   11  \
# ...

# %%
data_y_ = df.iloc[:,-1]
unique, counts = np.unique(data_y_, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 47132, 1: 52868}

# %%
del text_data, X, y, sequences
import gc
gc.collect()  # Giải phóng bộ nhớ
